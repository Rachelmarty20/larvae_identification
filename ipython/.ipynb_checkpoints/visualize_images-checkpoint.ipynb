# %%
import os
import mahotas as mh
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # 10 x 8 inches
plt.gray()

# %%
files = os.listdir('/cellar/users/ramarty/Data/ants/photos/')

# %%
im = mh.imread('/cellar/users/ramarty/Data/ants/photos/' + files[0])

# %%
im[1000:, 1000:]
# Out:
# array([[109, 111, 130, ...,  96, 103, 110],
#        [121, 117, 108, ...,  95, 107, 111],
#        [113, 106, 119, ...,  99,  99, 114],
#        ...,
#        [103, 104,  94, ...,  68,  50,  72],
#        [255, 255, 255, ..., 166, 201,  73],
#        [  0,   0,   0, ...,   0,   0,   0]], dtype=uint8)

# %%
print type(im)
print im.dtype
print im.shape
# y, x
plt.imshow(im[1120:2550, 900:2100])
# Out:
# <type 'numpy.ndarray'>
# uint8
# (4560, 3048)

# %%
for f in files[:10]:
    im = mh.imread('/cellar/users/ramarty/Data/ants/photos/' + f)
    print f
    plt.imshow(im[1120:2550, 900:2100])
    plt.show()
    plt.clf()
# Out:
# box31-20161208-1723-00006810.pgm
# box31-20161208-1751-00010170.pgm
# box31-20161208-1656-00003600.pgm
# box31-20161208-1727-00007290.pgm
# box31-20161208-1656-00003510.pgm
# box31-20161208-1747-00009630.pgm
# box31-20161208-1633-00000750.pgm
# box31-20161208-1706-00004710.pgm
# box31-20161208-1708-00005040.pgm
# box31-20161208-1728-00007380.pgm
